# %% [markdown]
# # Practica 5

# %% [markdown]
# ## Regresion logistica

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Cargamos e importamos las librerias necesarias

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from  sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
#Cargamos el data set
pd.options.display.max_colwidth = 200
df = pd.read_csv("C:/Users/Angel/Downloads/breast-cancer.csv", sep=',', engine='python') #Cargamos el data set 
X = df.drop(columns=['diagnosis'],axis = 1).values
y = df['diagnosis'].values 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle = False,random_state=0)

# %%
#Regresion logistica y procedimiento 

RegresionLogisticaProcess = LogisticRegression()
RegresionLogisticaProcess.fit(X_train,y_train)
Yprediccion = RegresionLogisticaProcess.predict(X_test)
print ('\n Clase real', y_test)
print ('\n Clase predicha', Yprediccion,'\n\n')
# Out:
#  Clase real ['M' 'B' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'M' 'M'
#  'M' 'M' 'B']
#
#  Clase predicha ['B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B']

# %%
#Matriz de Confusion Parte1

print('\nMatriz de confusión')
print(confusion_matrix(y_test, Yprediccion))
print('\nAccuracy')
print('Porcentaje de instancias predichas correctamente',accuracy_score(y_test, Yprediccion)) 
print('Cantidad de instancias predichas correctamente',accuracy_score(y_test, Yprediccion, normalize=False), '\n\n')
# Out:
# Matriz de confusión
# [[43  0]
#  [14  0]]
#
# Accuracy
# Porcentaje de instancias predichas correctamente 0.7543859649122807
# Cantidad de instancias predichas correctamente 43

# %%
#Matriz de Confusion Parte2

cm = confusion_matrix(y_test, Yprediccion,labels= RegresionLogisticaProcess.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=RegresionLogisticaProcess.classes_)
disp.plot()

# %%
#Matriz de Confusion Parte3

y_pred_proba = RegresionLogisticaProcess.predict_proba(X_test) 
print ('\n Probabilidad de pertenecer a una clase\n', y_pred_proba ,'\n\n')
plt.show()
# Out:
#  Probabilidad de pertenecer a una clase
#  [[0.50008143 0.49991857]
#  [0.50008145 0.49991855]
#  [0.50814483 0.49185517]
#  [0.50008148 0.49991852]
#  [0.50008153 0.49991847]
#  [0.50008153 0.49991847]
#  [0.50008155 0.49991845]
#  [0.50008156 0.49991844]
#  [0.50008156 0.49991844]
#  [0.50815978 0.49184022]
#  [0.50000816 0.49999184]
#  [0.50008163 0.49991837]
#  [0.50008163 0.49991837]
#  [0.50000816 0.49999184]
#  [0.50816431 0.49183569]
#  [0.50816431 0.49183569]
#  [0.50008166 0.49991834]
#  [0.50008168 0.49991832]
#  [0.50000817 0.49999183]
#  [0.50817233 0.49182767]
#  [0.50817233 0.49182767]
#  [0.50817469 0.49182531]
#  [0.50008177 0.49991823]
#  [0.50008178 0.49991822]
#  [0.50817907 0.49182093]
#  [0.5000818  0.4999182 ]
#  [0.50008191 0.49991809]
#  [0.50008194 0.49991806]
#  [0.50008194 0.49991806]
#  [0.50008194 0.49991806]
#  [0.50008196 0.49991804]
#  [0.50008202 0.49991798]
#  [0.50008202 0.49991798]
#  [0.50008205 0.49991795]
#  [0.50008205 0.49991795]
# ...
